# %%
"""docstring: I chose to do a game about Gossip Girl, because it is a show 
I grew up with. It used to be inspirational, as they show you contrast of 
the very wealthy living in Manhattan, but what really drew me in was its
portrayal of New York City, a city so vibrant and alive that felt like the
perfect place to live in.

When I got accepted into Hult, it no longer felt like a dream, but within 
grasp. I plan to get an internship there when I am done studying here, so it
felt like the right show to base this game on!

The Thanksgiving episodes were always great, because they would always show 
flashbacks from past festivities, and it seemed only fitting given that
November is almost here!

Hope you enjoy it."""

#introduction adapted from the show with format line for better use experience
print(f"""

{'_'*80}

Hey Hultians!

Gossip Girl here, your one and only source into the scandalous life of 
Manhattan’s elite. 
""")

#input so the user can read first and move on when they are ready
input(prompt = 'Press Enter to continue\n')

#giving information on the main characters
print(f"""{'_'*80}

We all know Blair Waldorf and Serena van der Woodsen, the self-proclaimed and 
actual queen of the Upper East Side. You’d think they’d be enemies, right? 

Well, they’re actually best friends… most of the time, anyways.

While Blair can be a little bossy and must always have her way, 
Serena is rather nonchalant and carefree, which gets her into 
trouble more often than not. 
""")

#input so the user can read move on when they are ready
input(prompt = 'Press Enter to continue\n')

#establishing goal of the game
print(f"""{'_'*80}

It’s the first Thanksgiving since Serena has been back from boarding 
school, and let’s just say she doesn’t always make it on time for 
dinner with her family. 

This year, Blair is going to help her out so Lily — her mom — doesn’t 
send her away once again.
""")

#input so the user can read move on when they are ready
input(prompt = 'Press Enter to continue\n')

#establishing goal of the game
print(f"""{'_'*80}

Oh, and I know you might be wondering… who am I? 

That’s a secret I’ll never tell.

You know you love me. 

XOXO, Gossip Girl.
""")

#input to start the game
input(prompt = 'Press Enter to start playing\n')

#defining first stage: The nigh before Thanksgiving
def stage_1():
    
    #printing initial message of stage 1
    print(f"""
{'_'*80}

It’s the night before Thanksgiving. Serena is at Blair’s having 
Martinis, because why not. I mean, it’s their usual Thursday night. 

Nate, Blair’s boyfriend — who Serena secretly hooked up with last 
spring — is suggesting to go out for drinks.

What should Blair and Serena do?
    
1. Go out for drinks.
2. Stay at Blair's.
""")
    
    #creating loop to avoid unexpected inputs for choice 1
    while True:
        
        #defining the first choice: drinks or home
        choice_1 = input(prompt = "Write 1 or 2, and press Enter.\n")
    
        #conditional if drinks 
        if choice_1 == "1":
            
            print("""
The three of them get to Visconti's with Blair’s driver, and the party is great.

What should they order?
        
1. Bottle of Whiskey
2. Tequila shots
""")
            
            #creating loop to avoid unexpected inputs for choice 2
            while True:
            
                #defining second choice: whiskey or tequila
                choice_2 = input(prompt = "Write 1 or 2, and press Enter.\n")
        
                #conditional if whiskey
                if choice_2 == "1":
                    print("""
Carter Baizen — Serena’s toxic on-and-off guy — arrives to Visconti’s 
and wants to dance with Serena.
        
Should Blair let him?

1. Yes, Serena will dance with Carter.
2. What is she thinking? Of course not.
""")
        
                    #creating loop to avoid unexpected inputs for choice 3
                    while True:
                    
                        #defining third choice: dancing or not  
                        choice_3 = input(prompt = "Write 1 or 2, and press Enter.\n")
        
                        #condition if Serena dances
                        if choice_3 == "1":
                            print("""
Serena is actually having a great time, but all that dancing has 
gotten her tired and now she wants to go home. 
        
Is Blair taking Serena home, or are they doing a sleepover at Blair’s?
    
1. Take Serena home.
2. Sleepover at Blair's.""")
                            
                            #creating loop to avoid unexpected inputs for choice 4
                            while True:
                        
                                #defining fourth choice: taking Serena home or sleeping at Blair's
                                choice_4 = input(prompt = "Write 1 or 2, and press Enter.\n")
            
                                #condition if they take Serena home
                                if choice_4 == "1":
                                    print(f"""
Great job! You took Serena home so she can rest up for tomorrow!
                                    """)
                                    
                                    #input to continue with story
                                    input(prompt = 'Press Enter to continue\n')
                                    
                                    #this takes us to stage 2
                                    stage_2()
                                    break
            
                                #condition if they go to Blair's
                                elif choice_4 == "2":
                                    
                                    print(f"""
Good job! Blair will make sure Serena is ready for tomorrow!
                                    """)
                                    
                                    #input to continue with story
                                    input(prompt = 'Press Enter to continue\n')
                                    
                                    #this takes us to stage 3
                                    stage_3()
                                    break
                            
                                #avoiding unexpected inputs for choice 4
                                elif choice_4 != "1" and choice_4 != "2":
                                    print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                                    
                                #setting else to catch bugs
                                else:
                                    print("""Something went wrong! Please try again.""")
                            
                                #break the loop
                                break
                                    
                        #conditional is Serena doesn't dance
                        elif choice_3 == "2":
                            
                            print("""
Since Blair did not let Serena dance with Carter, she basically 
downed the whole bottle of Whiskey on her own. Blair and Nate 
are already falling asleep and wanna go home. 

Should they force Serena into a cab, or go home and leave her behind?
    
1. Take Serena back to Blair's.
2. Leave Serena behind.
""")
                            #defining fifth choice: Blair's or Carter
                            choice_5 = input(prompt = "Write 1 or 2, and press Enter.\n")
                            
                            #creating loop to avoid unexpected inputs for choice 5
                            while True:
                        
                                #condition if they take Serena to Blair's
                                if choice_5 == "1":
                                    
                                    print(f"""
It’s great they didn’t leave her behind. Only God knows what 
would have happened if she had found her way to Carter again. 
                
Blair will make sure Serena is ready for tomorrow!
""")
                                    
                                    #input to continue with story
                                    input(prompt = 'Press Enter to continue\n')
                                    
                                    #this takes us to stage 3
                                    stage_3()
                                    break
            
                                #condition if leave Serena behind
                                elif choice_5 == "2":
                                    
                                    print(f"""
Serena found her way to Carter and left with him. Only God knows 
where they’re headed, the last time they ended up in Rome.
""")
                                    #this takes us to fail
                                    fail()
                                    break
                                
                                #avoiding unexpected inputs for choice 5
                                elif choice_5 != "1" and choice_5 != "2":
                                    print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                                
                                #setting else to catch bugs
                                else:
                                    print("""Something went wrong! Please try again.""")
                            
                                #break the loop
                                break
                        
                        #avoiding unexpected inputs for choice 3
                        elif choice_3 != "1" and choice_3 != "2":
                            print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                            
                        #setting else for bugs    
                        else:
                            print("""Something went wrong! Please try again.""")
                    
                        #break the loop
                        break
                    
                #conditional if tequila 
                elif choice_2 == "2":
                    
                    print("""
We all know how much Serena loves Tequila, so now she’s very drunk.
Carter Baizen — Serena’s toxic on-and-off guy — is at Visconti’s 
and Serena sneaks out the back to go somewhere else with him.
        
Where do you think they're going?

1. Clubbing.
2. Back to Carter's place.""")
            
                    #setting loop to avoid unexpected inputs for choice 6
                    while True:
                        
                        #defining sixth choice: Carter's or Club
                        choice_6 = input(prompt = "Write 1 or 2, and press Enter.\n")
            
                        #condition if they go clubbing
                        if choice_6 == "1":
                            
                            print(f"""
Without a doubt, they went to 1OAK. 
                
A few hours have passed and Serena is kind of tired, so she’s going back home.
                            """)
                            
                            #input to continue with story
                            input(prompt = 'Press Enter to continue\n')
                            
                            #this takes us to stage 2: Serena's place
                            stage_2()
                            break
            
                        #condition if they go back to Carter's
                        elif choice_6 == "2":
                            
                            print(f"""
Yeah, they went to Carter’s, and then flew to Los Angeles on Carter’s jet.
""")
                            #this takes us to the failing message
                            fail()
                            break
                                                       
                        elif choice_6 != "1" and choice_6 != "2":
                            print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                            
                        else:
                            print("""Something went wrong! Please try again.""")
                    
                        #break the loop
                        break
                            
                #avoiding unexpected inputs for choice 2
                elif choice_2 != "1" and choice_2 != "2":
                    print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                
                #setting else for bugs
                else:
                    print("""Something went wrong! Please try again.""")
            
                #break the loop
                break
                    
        #conditional if home        
        elif choice_1 == "2":
            
            print("""
Safe choice! Less temptations at Blair's. However, they still want to do something. 
    
Should they drink something, or order take out and watch a movie?
    
1. Play drinking games.
2. Order vietnamese and watch one of Audrey Hepburn's films.
""")
        
            #setting loop to avoid unexpected inputs for choice 7
            while True:
                
                #defining seventh choice: drinking games or take out
                choice_7 = input(prompt = "Write 1 or 2, and press Enter.\n")
        
                #condition if they play drinking games
                if choice_7 == "1":
                    
                    print(f"""
Blair is drunk and falls asleep, so Nate decides to talk to Serena about 
what happened last spring.
            
What should Serena do?
            
1. Say she's tired and try to sleep.
2. Talk to Nate.
""")
            
                    #setting loop to avoid unexpected inputs for choice 8
                    while True:
                    
                        #defining eight choice: dodge or talk
                        choice_8 = input(prompt = "Write 1 or 2, and press Enter.\n")
                    
                        #condition if she dodges Nate's question
                        if choice_8 == "1":
                            
                            print(f"""
Serena dodges the question pretending to be drunk and tired, and tells Nate 
it's probably better if he goes home, as she will be staying with Blair.
                
Nate leaves and crisis averted! Serena is ashamed of what happened last spring. 
That's the actual reason she left for boarding school.
""")
                            
                            #input to continue with story
                            input(prompt = 'Press Enter to continue\n')
                            
                            #this takes us to stage 3
                            stage_3()
                            break
                    
                        #condition if she talk to Nate
                        elif choice_8 == "2":
                            
                            print(f"""
Serena decides to talk to Nate about what happened last spring. Blair overhears 
them talking and can't believe what happened. Her best friend and her boyfriend?
                
She kicks them out and Serena, feeling ashamed, decides to go out and 
drink to avoid facing what just happened.
""")
                            #this takes us to fail
                            fail()
                            break
                        
                        #avoiding unexpected inputs for choice 8
                        elif choice_8 != "1" and choice_8 != "2":
                            print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                            
                        #setting else for bugs
                        else:
                            print("""Something went wrong! Please try again.""")
                            
                        #break the loop
                        break
            
                #condition if they order take out and watch movies
                elif choice_7 == "2":
                    
                    print(f"""
The food is over, and Nate doesn't really like Audrey's movies that much, 
so he goes home.
            
Blair and Serena decide to:
            
1. Paint their nails and do a sleepover at Blair's.
2. Call it a night and Serena goes home.
""")
                    
                    #setting loop to avoid unexpected inputs for choice 9
                    while True:
                        
                        #defining ninth choice
                        choice_9 = input(prompt = "Write 1 or 2, and press Enter.\n")
                        
                        #condition if they sleep at Blair's
                        if choice_9 == "1":
                            print(f"""
Great choice! The girls bonded over this time and went to bed early.
""")
                            
                            #input to continue with story
                            input(prompt = "Press Enter to continue\n")
                            
                            #this takes us to stage 3: Blair's place
                            stage_3()
                            break
                        
                        #condition if Serena goes home
                        elif choice_9 == "2":
                            
                            print(f"""
Good! Serena went home. A little later than expected, but home.
""")
                            
                            #input to continue with story
                            input(prompt = 'Press Enter to continue\n')
                    
                            #this takes us to stage 2: Serena's place
                            stage_2()
                            break
                        
                        #avoiding unexpected inputs for choice 9
                        elif choice_9 != "1" and choice_9 != "2":
                            print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                            
                        #setting else for bugs
                        else:
                            print("""Something went wrong! Please try again.""") 
                    
                        #break the loop
                        break
                            
                #avoiding unexpected inputs for choice 7
                elif choice_7 != "1" and choice_7 != "2":
                    print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
            
                #setting else for bugs
                else:
                    print("""Something went wrong! Please try again.""")
            
                #break the loop
                break
                    
        #avoiding unexpected inputs for choice 1
        elif choice_1 != "1" and choice_1 != "2":
            print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
        
        #setting else to catch bugs
        else:
            print("""Something went wrong! Please try again.""")
            
#defining stage 2: Serena went home
def stage_2():
    
    #printing initial message of stage 2
    print(f"""
{'_'*80}

It's Thanksgiving Day, and Serena wakes up hungover. 
Her mom heard her arrive past curfew, so she’s definitely in trouble. 
    
What should she do?
    
1. Go down for breakfast and apologize to her mom for staying out late.
2. Find some excuse to leave the apartment and avoid the lecture.
""")
    
    #setting loop to avoid unexpected inputs for choice 10
    while True:
        
        #defining 10th choice: apologize or avoid lecture
        choice_10 = input(prompt = "Write 1 or 2, and press Enter.\n")
        
        #condition if she apologizes
        if choice_10 == "1":
            
            print(f"""
Serena goes down for breakfast and apologizes. Lily gives her a lecture as expected.
                    
She is starting to get annoyed...
            
1. but she knows her mom is right, so she offers to help with dinner.
2. so she starts screaming at her mom.
""")
            
            #setting loop to avoid unexpected inputs for choice 11
            while True:
                
                #defining 11th choice
                choice_11 = input(prompt = "Write 1 or 2, and press Enter.\n")
                
                #condition if she offers to help
                if choice_11 == "1":
                    
                    print(f"""
Great! Apparently Serena can change. Lily is pleased with her new behavior.
Dinner will be a hit!
""")
                    
                    #input to continue with story
                    input(prompt = 'Press Enter to continue\n')
                    
                    #this takes us to stage 4: Thanksgiving dinner
                    stage_4()
                    break
                
                #condition if she lashes out at her mom
                elif choice_11 == "2":
                    
                    print("""
Oh no, Serena lashed out at her mom. It seems like boarding school did not help.
                    
Another Thanksgiving ruined!
""")
                    #this takes us to fail
                    fail()
                    break
                    
                #avoiding unexpected inputs for choice 11
                elif choice_11 != "1" and choice_11 != "2":
                    print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
        
                #setting else to catch bugs
                else:
                    print("""Something went wrong! Please try again.""")
            
                #break the loop
                break
                    
        #condition if she avoids lecture
        elif choice_10 == "2":
            
            print("""
Serena makes up an excuse and is headed to Blair's house.
            
She walks past The Evercake on her way, and they have the most amazing pies on display.
However, there is a Neiman Marcus store just around the corner.
            
What do you think she'll do?
            
1. Get a punpkin pie from The Evercake and go back home.
2. Go on a classic Serena shopping spree.
""")
            
            #setting loop to avoid unexpected inputs for choice 12
            while True:
                
                #defining 12th choice
                choice_12 = input(prompt = "Write 1 or 2, and press Enter.\n")
                
                #condition if Serena takes the pie home
                if choice_12 == "1":
                    
                    print("""
Great! Serena got the pie and that will for sure make Lily happy!
                    
It seems like she did change in boarding school after all!
""")
                    
                    #input to continue with story
                    input(prompt = 'Press Enter to continue\n')
                    
                    #this takes us to stage 4
                    stage_4()
                    break
                    
                #condition if she goes on a shopping spree
                elif choice_12 == "2":
                    
                    print("""
Oh boy, Serena usually takes hours when she goes shopping.
                    
It seems like she won't make it back home in time for dinner.
""")
                    #this takes us to fail
                    fail()
                    break
                    
                #avoiding unexpected inputs for choice 12
                elif choice_12 != "1" and choice_12 != "2":
                    print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                    
                #setting else to catch bugs
                else:
                    print("""Something went wrong! Please try again.""")
                
                #break the loop
                break
            
        #avoiding unexpected inputs
        elif choice_10 != "1" and choice_10 != "2":
            print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
        
        #setting else to catch bugs
        else:
            print("""Something went wrong! Please try again.""") 
    
        #break the loop
        break
            
#defining stage 3: Blair's place
def stage_3():
  
    #printing initial message of stage 3
    print(f"""{'_'*80}
    
It's Thanksgiving Day and Serena wakes up at Blair's. The first thing she sees when
she grabs her phone is a text from Chuck, the rich boy at school, inviting her to a
Thanksgiving party!
    
What should she do?
    
1. Go to Chuck's party.
2. Stay and have brunch at the Waldorfs'.
""")
    
    #setting loop to avoid unexpected inputs for choice 13
    while True:
        
        #defining 13th choice: brunch at the Waldorf's or Chuck's party
        choice_13 = input(prompt = "Write 1 or 2, and press Enter.\n")
        
        #condition if she goes to the party
        if choice_13 == "1":
            
            print(f"""
Oh, oh! Chuck's parties usually go wild. Since his father is not around
he doesn't really care too much about the festivities.
                    
A couple of hours have gone by and Georgina, and old friend of Serena shows up.
            
What should Serena do?
            
1. Say hi, but leave to buy a pie and go home.
2. Stay with Georgina at the party.
""")
            
            #setting loop to avoid unexpected inputs for choice 14
            while True:
                
                #defining 14th choice
                choice_14 = input(prompt = "Write 1 or 2, and press Enter.\n")
                
                #condition if she leaves
                if choice_14 == "1":
                    
                    print(f"""
Great! Even though Serena went to the party, she now has time to freshen up
and show up for dinner, and with a pie!
""")
                    
                    #input to continue with story
                    input(prompt = 'Press Enter to continue\n')
                    
                    #this takes us to stage 4: Thanksgiving dinner
                    stage_4()
                    break
                
                #condition if she stays with Georgina
                elif choice_14 == "2":
                    
                    print("""
Oh no, Georgina put something in Serena's drink and she didn't go back home.
Classic Georgina. After all, their friendship was always very toxic.
                    
Another Thanksgiving ruined!
""")
                    #this takes us to fail
                    fail()
                    break
                    
                #avoiding unexpected inputs for choice 14
                elif choice_14 != "1" and choice_14 != "2":
                    print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
        
                #setting else to catch bugs
                else:
                    print("""Something went wrong! Please try again.""")
            
                #break the loop
                break
                    
        #condition if she stays for brunch at the Waldorfs'
        elif choice_13 == "2":
            
            print("""
That's great. Even Blair's father, who lives in France, made it on time for brunch.
This is giving the girls time to bond.
            
However, Chuck is being persistent.
            
What should Serena do?
            
1. Ignore Chuck. Blair's father has a great pie recipe.
2. Go to Chuck's party.
""")
            
            #setting loop to avoid unexpected inputs for choice 15
            while True:
                
                #defining 15th choice
                choice_15 = input(prompt = "Write 1 or 2, and press Enter.\n")
                
                #condition if Serena stays
                if choice_15 == "1":
                    print("""
Great! Blair's dad taught Serena the recipe and now she has a pie
to bring back home for her dinner.
                    
It seems like she did change in boarding school after all!
""")
                    
                    #input to continue with story
                    input(prompt = 'Press Enter to continue\n')
                    
                    #this takes us to stage 4
                    stage_4()
                    break
                    
                #condition if she goes to the party
                elif choice_15 == "2":
                    
                    print("""
Oh boy, things do not seem to change. Serena went to Chuck's and 
it seems like she won't make it back home in time for dinner.
""")
                    #this takes us to fail
                    fail()
                    break
                    
                #avoiding unexpected inputs for choice 15
                elif choice_15 != "1" and choice_15 != "2":
                    print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                    
                #setting else to catch bugs
                else:
                    print("""Something went wrong! Please try again.""")
                                 
                #break the loop
                break
            
        #avoiding unexpected inputs for choice 13
        elif choice_13 != "1" and choice_13 != "2":
            print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
        
        #setting else to catch bugs
        else:
            print("""Something went wrong! Please try again.""")
            
        #break the loop        
        break

#defining stage 4: Thanksgiving dinner
def stage_4():
    
    #printing initial message of stage 4
    print(f"""
{'_'*80}

Good! Serena made it back home in time for Thanksgiving Dinner but that was 
just half the job. Now, let's see how dinner goes.
""")
    
    #input to continue with story
    input(prompt = 'Press Enter to continue\n')
    
    print(f"""
{"_"*80}
    
Lily calls for a toast and announces she is engaged to Chuck's father, Bart Bass, 
one of the richest men in New York.
    
Since it was a little out of the blue, things got a little uncomfortable.
    
What should Serena do?
    
1. Act as if nothing happened and help out setting the table.
2. Talk to Lily.
""")
    
    #setting loop to avoid unexpected inputs for choice 16
    while True:
        
        #defining 16th choice: help with the table, or talk to Lily
        choice_16 = input(prompt = "Write 1 or 2, and press Enter.\n")
        
        #condition if she helps with the table
        if choice_16 == "1":
            
            print(f"""
Good choice! Maybe talking to Lily wouldn't have been smart, considering 
Serena doesn't even like Chuck that much.
                    
Serena finds her brother Eric in the kitchen as well, and they start
talking about what just happened.
            
Oh, oh! Something smells like burning. They were supposed to help but 
forgot to turn the oven off and now the turkey is all scorched.
""")
            
            #input to move forward to losing message
            input(prompt = 'Press Enter to continue\n')
                   
            #this takes us to losing
            fail()
            break
            
        #condition if she talks to Lily
        elif choice_16 == "2":
            
            print("""
Serena decides to talk to her mom, because she didn't even know she was
dating Bart.

How should Serena approach the conversation?
            
1. She should be supportive, even if this is husband #4.
2. What was she thinking? Serena will confront her.
""")
            
            #setting loop to avoid unexpected inputs for choice 17
            while True:
                
                #defining 17th choice
                choice_17 = input(prompt = "Write 1 or 2, and press Enter.\n")
                
                #condition if Serena is supportive
                if choice_17 == "1":
                    
                    print("""
Even though Serena is a little adamant about the whole situation, she shows 
support. She likes Bart better than her mom's previous husband anyways.
                    
It seems like she did change in boarding school after all!
""")
                    
                    #input to move forward to winning message
                    input(prompt = 'Press Enter to continue\n')
                    
                    #this takes us to the winning message
                    win()
                    break
                    
                #condition if she goes to the party
                elif choice_17 == "2":
                    
                    print("""
Oh, oh! Serena is mad. She doesn't even like Chuck that much and she 
feels a little betrayed that her mom did not tell her anything before,
considering this also affects her life!
                    
They start arguing and things go south.
""")
                    
                    #input to move forward to losing message
                    input(prompt = 'Press Enter to continue\n')
                   
                    #this takes us to losing
                    fail()
                    break
                    
                #avoiding unexpected inputs for choice 17
                elif choice_17 != "1" and choice_17 != "2":
                    print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
                    
                #setting else to catch bugs
                else:
                    print("""Something went wrong! Please try again.""")
           
                #break the loop
                break
            
        #avoiding unexpected inputs for choice 16
        elif choice_16 != "1" and choice_16 != "2":
            print("""\nI was expecting a number, 1 or 2. Would you like to try that again?""")
        
        #setting else to catch bugs
        else:
            print("""Something went wrong! Please try again.""")
            
        #break the loop    
        break
    
#defining fail message
def fail():
    print("""
On the Upper East Side, tradition is upheld with a bountiful harvest 
of secrets, lies and scandals. Better luck next time.
    
XOXO, Gossip Girl.
""")
    
    #input to exit
    input(prompt = "Press Enter to Exit.\n")
    
#defining winning message
def win():
    print("""
CONGRATS! You took Serena back home in time for Thanksgiving Dinner,
and averted a crisis.
    
I do love a scandal, but I'll let it pass for now.
    
Luckily the things that have been slowly simmering always taste the most satisfying. 
Bon appetit.
    
XOXO, Gossip Girl.
""")
    
    #input to exit
    input(prompt = "Press Enter to exit.\n")
    
#activating game
stage_1()
# Out:
# ________________________________________________________________________________
#
# Hey Hultians!
#
# Gossip Girl here, your one and only source into the scandalous life of
# Manhattan’s elite.
#
# Press Enter to continue
#
# ________________________________________________________________________________
#
# We all know Blair Waldorf and Serena van der Woodsen, the self-proclaimed and
# actual queen of the Upper East Side. You’d think they’d be enemies, right?
#
# Well, they’re actually best friends… most of the time, anyways.
#
# While Blair can be a little bossy and must always have her way,
# Serena is rather nonchalant and carefree, which gets her into
# trouble more often than not.
#
# Press Enter to continue
#
# ________________________________________________________________________________
#
# It’s the first Thanksgiving since Serena has been back from boarding
# school, and let’s just say she doesn’t always make it on time for
# dinner with her family.
#
# ...
